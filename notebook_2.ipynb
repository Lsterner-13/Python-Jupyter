# %% [markdown]
# # This notebook is ready for your projects and experiments
#
# Go ahead and code!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("happyscore_income.csv")

# %%
df
# Out:
#                 country  adjusted_satisfaction  avg_satisfaction  \
# 0               Armenia                   37.0               4.9
# 1                Angola                   26.0               4.3
# 2             Argentina                   60.0               7.1
# 3               Austria                   59.0               7.2
# 4             Australia                   65.0               7.6
# 5            Azerbaijan                   46.0               5.8
# 6            Bangladesh                   43.0               5.3
# 7               Belgium                   63.0               7.2
# 8          Burkina Faso                   37.0               4.4
# 9              Bulgaria                   34.0               4.6
# 10              Burundi                   25.0               2.9
# 11                Benin                   20.0               3.0
# 12              Bolivia                   53.0               6.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 11 columns):
# country                  111 non-null object
# adjusted_satisfaction    111 non-null float64
# avg_satisfaction         111 non-null float64
# std_satisfaction         111 non-null float64
# avg_income               111 non-null float64
# median_income            111 non-null float64
# income_inequality        111 non-null float64
# region                   111 non-null object
# happyScore               111 non-null float64
# GDP                      111 non-null float64
# country.1                111 non-null object
# dtypes: float64(8), object(3)
# memory usage: 9.6+ KB

# %%
df["happyScore"].value_counts()
# Out:
# 6.983    1
# 4.694    1
# 7.119    1
# 4.739    1
# 6.329    1
# 7.427    1
# 6.574    1
# 5.975    1
# 5.824    1
# 4.514    1
# 4.610    1
# 4.350    1
# 3.681    1
# 6.937    1
# 5.429    1
# 4.436    1
# 5.129    1
# 3.931    1
# 4.786    1
# 5.759    1
# 5.689    1
# 7.378    1
# 7.587    1
# 4.642    1
# 5.332    1
# 4.419    1
# 6.946    1
# 4.686    1
# 4.332    1
# 5.098    1
#         ..
# 5.013    1
# 5.360    1
# 3.667    1
# 4.681    1
# 6.670    1
# 4.788    1
# 6.940    1
# 5.212    1
# 4.033    1
# 4.369    1
# 3.465    1
# 4.876    1
# 4.874    1
# 2.839    1
# 4.898    1
# 5.889    1
# 5.477    1
# 3.904    1
# 6.455    1
# 4.800    1
# 6.575    1
# 5.399    1
# 7.278    1
# 4.633    1
# 3.819    1
# 4.571    1
# 5.948    1
# 7.200    1
# 5.791    1
# 6.750    1
# Name: happyScore, Length: 111, dtype: int64

# %%
df.groupby(by="region").mean()
# Out:
#                                    adjusted_satisfaction  avg_satisfaction  \
# region
# 'Australia and New Zealand'                    65.000000          7.600000
# 'Central and Eastern Europe'                   46.000000          5.717391
# 'Eastern Asia'                                 48.666667          6.100000
# 'Latin America and Caribbean'                  59.062500          7.187500
# 'Middle East and Northern Africa'              47.800000          5.980000
# 'North America'                                65.500000          7.650000
# 'Southeastern Asia'                            52.142857          6.242857
# 'Southern Asia'                                44.600000          5.440000
# 'Sub-Saharan Africa'                           34.833333          4.380000
# 'Western Europe'                               62.736842          7.321053
#
#                                    std_satisfaction    avg_income  \
# region
# ...

# %%
df2 = df.groupby(by="region").mean()

# %%
df2
# Out:
#                                    adjusted_satisfaction  avg_satisfaction  \
# region
# 'Australia and New Zealand'                    65.000000          7.600000
# 'Central and Eastern Europe'                   46.000000          5.717391
# 'Eastern Asia'                                 48.666667          6.100000
# 'Latin America and Caribbean'                  59.062500          7.187500
# 'Middle East and Northern Africa'              47.800000          5.980000
# 'North America'                                65.500000          7.650000
# 'Southeastern Asia'                            52.142857          6.242857
# 'Southern Asia'                                44.600000          5.440000
# 'Sub-Saharan Africa'                           34.833333          4.380000
# 'Western Europe'                               62.736842          7.321053
#
#                                    std_satisfaction    avg_income  \
# region
# ...

# %%
plt.figure(figsize=(30,20))
sns.barplot(x=df2.index, y=df2.happyScore, data=df2)
plt.title("Mean Happy Score by Region", size=20)
plt.xlabel("Region", size=20)
plt.ylabel("Mean Happy Score", size=20)

plt.show()

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("Banknote-authentication-dataset-.csv")

# %%
plt.figure(figsize = [7, 7])
plt.scatter(df.V1, df.V2);

# %%
from sklearn.datasets.samples_generator import (make_blobs,
                                                make_circles,
                                                make_moons)
from sklearn.cluster import KMeans, SpectralClustering

data = np.column_stack(( df.V1, df.V2))  # we use only V1 and V2

# compute K-Means
km_res = KMeans(n_clusters = 2).fit(data)
clusters = km_res.cluster_centers_

# put the assigned labels to the original dataset
df['KMeans'] = km_res.labels_

#plot out the result
g = sb.FacetGrid(data = df, hue = 'KMeans', size = 5)
g.map(plt.scatter, 'V1', 'V2')
g.add_legend();
plt.scatter(clusters[:,0], clusters[:,1], s=500, marker='*', c='r')
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.datasets.samples_generator import (make_blobs,
                                                make_circles,
                                                make_moons)
from sklearn.cluster import KMeans, SpectralClustering

n_iter = 9
fig, ax = plt.subplots(3, 3, figsize=(16, 16))
ax = np.ravel(ax)
centers = []
for i in range(n_iter):
    # Run local implementation of kmeans
    km = KMeans(n_clusters=2,
                max_iter=3)
    km.fit(data)
    centroids = km.cluster_centers_
    centers.append(centroids)
    ax[i].scatter(data[km.labels_ == 0, 0], data[km.labels_ == 0, 1],
                   label='cluster 1')
    ax[i].scatter(data[km.labels_ == 1, 0], data[km.labels_ == 1, 1],
                   label='cluster 2')
    ax[i].scatter(centroids[:, 0], centroids[:, 1],
                  c='r', marker='*', s=300, label='centroid')
    ax[i].legend(loc='lower right')
    ax[i].set_aspect('equal')
plt.tight_layout();

# %%
df.groupby('KMeans').describe()
# Out:
#            V1                                                                \
#         count      mean       std     min      25%      50%     75%     max
# KMeans
# 0       599.0 -0.125914  2.655152 -5.2943 -2.18825 -0.65767  2.0159  5.7403
# 1       773.0  0.867409  2.908508 -7.0421 -0.95403  1.11660  3.1896  6.8248
#
#            V2
#         count      mean       std      min      25%     50%       75%      max
# KMeans
# 0       599.0 -3.479989  3.834604 -13.7731 -6.30615 -2.9363 -0.066226   1.6327
# 1       773.0  6.108644  3.096698   1.0367  3.25700  6.1437  8.794400  12.9516

# %%
# plot the data computed by K-Means
g = sb.FacetGrid(data = df, hue = 'KMeans', size = 5)
g.map(plt.scatter, 'V1', 'V2')
g.add_legend()
plt.title("K-Means Result");
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# correct the labels
df["KMeans"] = df["KMeans"].map({0: 1, 1: 2})

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# Normalize the data
min_vals = np.min(data, axis=0)
max_vals = np.max(data, axis=0)
normed = (data - min_vals) / (max_vals - min_vals)

# Compute mean and standard deviation
mean = np.mean(normed, axis=0)
std_dev = np.std(normed, axis=0)

# Create an ellipse using mean and standard deviation
ellipse = Ellipse(
    [mean[0], mean[1]], 
    std_dev[0] * 2,  # Width of the ellipse
    std_dev[1] * 2,  # Height of the ellipse
    alpha=0.25
)

# Plotting
fig, ax = plt.subplots()
ax.add_patch(ellipse)
ax.scatter(normed[:, 0], normed[:, 1], label='Data Points')

# Configure plot
ax.set_xlim(0, 1)  # Assuming data is normalized between 0 and 1
ax.set_ylim(0, 1)
ax.set_aspect('equal', 'box')
ax.legend()
plt.title("Normalized Data with Ellipse")
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.show()

# %%
import numpy as np

min_vals = np.min(data, axis=0)
max_vals = np.max(data, axis=0)
std_dev = np.std(data, axis=0)

# Print the results
print("Minimum values:", min_vals)
print("Maximum values:", max_vals)
print("Standard deviations:", std_dev)
# Out:
# Minimum values: [ -7.0421 -13.7731]
# Maximum values: [ 6.8248 12.9516]
# Standard deviations: [2.84172641 5.86690749]
